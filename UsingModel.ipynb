# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.57-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.13-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.12.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.57-py3-none-any.whl (905 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.3/905.3 kB 16.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.13-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.57 ultralytics-thop-2.0.13

# %%
from google.colab import drive
drive.mount('/content/drive')

# !ls "/content/drive/My Drive"

# !fusermount -u /content/drive
# !rm -rf /content/drive
# Out:
# Mounted at /content/drive
# '10-Nguyễn Công Thành.mkv'			   HTML
# '2402_Buoi03_ThanhNC(Tren_Lop).sql'		   Java
#  Android2.drawio				   K16_Testing11_nhom10
#  Android.drawio					  'K16_Testing11_nhom10 (1)'
#  ArtStoreProject.rar				  'Kiem thu'
#  Bài-tập-thuyết-trình-về-khu-vực.pptx		  'LeagueClient Logs.rar'
#  BBKH_TruongCongManh.docx			   Maven
#  BCKH_TruongCongManh.docx			   NgoaiNgu
# 'Biểu đồ ca sử dụng.gdoc'			  'Nguyễn Công Thành.pdf'
# 'BTL Học máy'					  'Nhóm 14 TTCSN'
#  BTL_N1_HocMay_final.docx			   Presentation4.pptx
# 'Buổi 1 - Giới thiệu HP gửi SV.pptx'		  'Professional statement exemplar.gdoc'
# 'Chương 1_2 MỘT SỐ GỢI Ý ĐỂ HỌC TỐT (1).gslides'  'Professional statement outline.gdoc'
# 'Chương 1_2 MỘT SỐ GỢI Ý ĐỂ HỌC TỐT (2).gslides'   Python
# 'Chương 1_2 MỘT SỐ GỢI Ý ĐỂ HỌC TỐT.gslides'	   Python.drawio
# 'Chương 2 Cơ bản về MT - CNTT (1).gslides'	   SQL
# 'Chương 2 Cơ bản về MT - CNTT (2).gslides'	  'Tên các use case.gdoc'
# 'Chương 2 Cơ bản về MT - CNTT.gslides'		   TestScore.png
#  Classroom					   TTDN.drawio
# 'Colab Notebooks'				   Untitled-2.ai
#  Cookingisfun.drawio				  'Untitled design.png'
# 'CV-Nguyễn Công Thành.pdf'			  'Untitled Diagram (1).drawio'
# 'Đặc tả các use case.gdoc'			  'Untitled Diagram (2).drawio'
# 'Đặc tả user .gdoc'				  'Untitled Diagram (3).drawio'
# 'EnglishScoreCertificate (1).png'		  'Untitled Diagram (4).drawio'
#  EnglishScoreCertificate.png			  'Untitled Diagram (5).drawio'
#  EnglishScore.png				  'Untitled Diagram.drawio'
# '[HAUI] CV Fresher-Nguyễn Công Thành.pdf.pdf'	   UseCase_PythonNC.drawio
# '[HAUI] CV Intern AI-Nguyễn Công Thành.pdf'	  'Ý tưởng riêng'

# %%
from ultralytics import YOLO

# model = YOLO('runs/detect/train/weights/best.pt')

model = YOLO('drive/MyDrive/Colab Notebooks/YOLO/train/Train3/best.pt')

# results = model.predict('drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4', save=True)
results = model.predict('drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4', save=True)

print(results[0])

print('------------------------------------------------------')

for box in results[0].boxes:
  print(box)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 23 players, 1 referee, 543.4ms
# video 1/1 (frame 2/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 22 players, 1 referee, 353.3ms
# video 1/1 (frame 3/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 24 players, 1 referee, 349.1ms
# video 1/1 (frame 4/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 22 players, 1 referee, 447.9ms
# video 1/1 (frame 5/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 21 players, 1 referee, 535.0ms
# video 1/1 (frame 6/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 21 players, 1 referee, 529.3ms
# video 1/1 (frame 7/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 23 players, 1 referee, 553.9ms
# video 1/1 (frame 8/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 25 players, 1 referee, 528.8ms
# video 1/1 (frame 9/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 23 players, 1 referee, 550.7ms
# video 1/1 (frame 10/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 2 goalkeepers, 20 players, 1 referee, 511.3ms
# video 1/1 (frame 11/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 22 players, 1 referee, 547.4ms
# video 1/1 (frame 12/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 23 players, 1 referee, 341.8ms
# video 1/1 (frame 13/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 20 players, 1 referee, 350.0ms
# video 1/1 (frame 14/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 20 players, 1 referee, 341.7ms
# video 1/1 (frame 15/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 19 players, 1 referee, 344.2ms
# video 1/1 (frame 16/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 21 players, 1 referee, 342.9ms
# video 1/1 (frame 17/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 20 players, 1 referee, 341.7ms
# video 1/1 (frame 18/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 21 players, 1 referee, 359.5ms
# video 1/1 (frame 19/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 22 players, 1 referee, 341.3ms
# video 1/1 (frame 20/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 21 players, 1 referee, 352.2ms
# video 1/1 (frame 21/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 21 players, 1 referee, 362.8ms
# video 1/1 (frame 22/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 19 players, 347.9ms
# video 1/1 (frame 23/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 18 players, 1 referee, 375.3ms
# video 1/1 (frame 24/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 19 players, 2 referees, 353.8ms
# video 1/1 (frame 25/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 20 players, 1 referee, 352.8ms
# video 1/1 (frame 26/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 2 goalkeepers, 21 players, 2 referees, 349.0ms
# video 1/1 (frame 27/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 19 players, 1 referee, 342.6ms
# video 1/1 (frame 28/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 22 players, 1 referee, 370.7ms
# video 1/1 (frame 29/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 21 players, 1 referee, 341.1ms
# video 1/1 (frame 30/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 22 players, 1 referee, 336.9ms
# video 1/1 (frame 31/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 21 players, 1 referee, 349.2ms
# video 1/1 (frame 32/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 22 players, 1 referee, 357.1ms
# video 1/1 (frame 33/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 27 players, 1 referee, 365.6ms
# video 1/1 (frame 34/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 21 players, 1 referee, 340.3ms
# video 1/1 (frame 35/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 20 players, 1 referee, 356.6ms
# video 1/1 (frame 36/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 20 players, 2 referees, 510.0ms
# video 1/1 (frame 37/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 19 players, 1 referee, 527.8ms
# video 1/1 (frame 38/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 20 players, 1 referee, 502.2ms
# video 1/1 (frame 39/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 24 players, 1 referee, 524.9ms
# video 1/1 (frame 40/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 25 players, 1 referee, 546.3ms
# video 1/1 (frame 41/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 21 players, 1 referee, 530.7ms
# video 1/1 (frame 42/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 21 players, 1 referee, 526.9ms
# video 1/1 (frame 43/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 20 players, 1 referee, 516.9ms
# video 1/1 (frame 44/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 19 players, 1 referee, 342.1ms
# video 1/1 (frame 45/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 18 players, 1 referee, 338.4ms
# video 1/1 (frame 46/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 18 players, 1 referee, 333.7ms
# video 1/1 (frame 47/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 18 players, 1 referee, 344.3ms
# video 1/1 (frame 48/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 19 players, 1 referee, 343.5ms
# video 1/1 (frame 49/49) /content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4: 384x640 1 goalkeeper, 18 players, 1 referee, 335.5ms
# Speed: 5.0ms preprocess, 410.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
# obb: None
# orig_img: array([[[ 26,  27,  37],
#         [ 26,  27,  37],
#         [ 25,  26,  36],
#         ...,
#         [ 99,  99,  83],
#         [ 87,  87,  71],
#         [ 65,  65,  49]],
#
#        [[ 20,  21,  31],
#         [ 21,  22,  32],
#         [ 21,  22,  32],
#         ...,
#         [ 84,  84,  68],
#         [ 71,  71,  55],
#         [ 58,  58,  42]],
#
#        [[ 21,  22,  32],
#         [ 24,  25,  35],
#         [ 24,  25,  35],
#         ...,
#         [ 70,  69,  56],
#         [ 61,  60,  47],
#         [ 56,  55,  42]],
#
#        ...,
#
#        [[ 38,  57,  43],
#         [ 37,  56,  42],
#         [ 34,  53,  39],
#         ...,
#         [ 66, 118,  97],
#         [ 66, 118,  97],
#         [ 66, 118,  97]],
#
#        [[ 38,  57,  43],
#         [ 37,  56,  42],
#         [ 34,  53,  39],
#         ...,
#         [ 66, 118,  97],
#         [ 66, 118,  97],
#         [ 64, 116,  95]],
#
#        [[ 38,  57,  43],
#         [ 37,  56,  42],
#         [ 34,  53,  39],
#         ...,
#         [ 66, 118,  97],
#         [ 66, 118,  97],
#         [ 64, 116,  95]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/drive/MyDrive/Colab Notebooks/YOLO/input_video/challenge-1003_2.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 19.884347915649414, 'inference': 543.4212684631348, 'postprocess': 37.032127380371094}
# ------------------------------------------------------
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8074])
# data: tensor([[1.7121e+03, 3.0267e+02, 1.7376e+03, 3.8563e+02, 8.0737e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1724.8363,  344.1505,   25.4685,   82.9559]])
# xywhn: tensor([[0.8984, 0.3187, 0.0133, 0.0768]])
# xyxy: tensor([[1712.1021,  302.6725, 1737.5706,  385.6284]])
# xyxyn: tensor([[0.8917, 0.2803, 0.9050, 0.3571]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.7745])
# data: tensor([[585.6912, 325.6868, 608.2608, 401.0354,   0.7745,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[596.9760, 363.3611,  22.5696,  75.3486]])
# xywhn: tensor([[0.3109, 0.3364, 0.0118, 0.0698]])
# xyxy: tensor([[585.6912, 325.6868, 608.2608, 401.0354]])
# xyxyn: tensor([[0.3050, 0.3016, 0.3168, 0.3713]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.7691])
# data: tensor([[8.7186e+02, 3.1713e+02, 8.9599e+02, 3.9572e+02, 7.6914e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[883.9240, 356.4261,  24.1315,  78.5966]])
# xywhn: tensor([[0.4604, 0.3300, 0.0126, 0.0728]])
# xyxy: tensor([[871.8582, 317.1278, 895.9897, 395.7244]])
# xyxyn: tensor([[0.4541, 0.2936, 0.4667, 0.3664]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.7687])
# data: tensor([[474.8904, 525.2782, 507.7718, 619.0555,   0.7687,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[491.3311, 572.1669,  32.8813,  93.7773]])
# xywhn: tensor([[0.2559, 0.5298, 0.0171, 0.0868]])
# xyxy: tensor([[474.8904, 525.2782, 507.7718, 619.0555]])
# xyxyn: tensor([[0.2473, 0.4864, 0.2645, 0.5732]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.7496])
# data: tensor([[1.1933e+03, 3.4703e+02, 1.2153e+03, 4.2322e+02, 7.4957e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1204.3411,  385.1256,   22.0033,   76.1898]])
# xywhn: tensor([[0.6273, 0.3566, 0.0115, 0.0705]])
# xyxy: tensor([[1193.3394,  347.0307, 1215.3427,  423.2205]])
# xyxyn: tensor([[0.6215, 0.3213, 0.6330, 0.3919]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.7414])
# data: tensor([[1.7078e+03, 4.2153e+02, 1.7357e+03, 5.1786e+02, 7.4138e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1721.7880,  469.6974,   27.9155,   96.3289]])
# xywhn: tensor([[0.8968, 0.4349, 0.0145, 0.0892]])
# xyxy: tensor([[1707.8302,  421.5330, 1735.7457,  517.8618]])
# xyxyn: tensor([[0.8895, 0.3903, 0.9040, 0.4795]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.7098])
# data: tensor([[456.0515, 376.1784, 486.1437, 464.3858,   0.7098,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[471.0976, 420.2821,  30.0923,  88.2074]])
# xywhn: tensor([[0.2454, 0.3892, 0.0157, 0.0817]])
# xyxy: tensor([[456.0515, 376.1784, 486.1437, 464.3858]])
# xyxyn: tensor([[0.2375, 0.3483, 0.2532, 0.4300]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.7055])
# data: tensor([[9.6183e+02, 3.6777e+02, 1.0015e+03, 4.5171e+02, 7.0552e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[981.6651, 409.7423,  39.6603,  83.9414]])
# xywhn: tensor([[0.5113, 0.3794, 0.0207, 0.0777]])
# xyxy: tensor([[ 961.8350,  367.7716, 1001.4952,  451.7130]])
# xyxyn: tensor([[0.5010, 0.3405, 0.5216, 0.4183]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.6842])
# data: tensor([[9.8644e+02, 2.8029e+02, 1.0062e+03, 3.4752e+02, 6.8415e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[996.2975, 313.9058,  19.7130,  67.2361]])
# xywhn: tensor([[0.5189, 0.2907, 0.0103, 0.0623]])
# xyxy: tensor([[ 986.4410,  280.2878, 1006.1540,  347.5239]])
# xyxyn: tensor([[0.5138, 0.2595, 0.5240, 0.3218]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.6819])
# data: tensor([[7.6925e+02, 3.2333e+02, 8.0329e+02, 3.9736e+02, 6.8186e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[786.2694, 360.3441,  34.0455,  74.0243]])
# xywhn: tensor([[0.4095, 0.3337, 0.0177, 0.0685]])
# xyxy: tensor([[769.2466, 323.3320, 803.2922, 397.3563]])
# xyxyn: tensor([[0.4006, 0.2994, 0.4184, 0.3679]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.6708])
# data: tensor([[1.1020e+03, 2.2175e+02, 1.1222e+03, 2.7563e+02, 6.7079e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1112.0972,  248.6893,   20.2072,   53.8743]])
# xywhn: tensor([[0.5792, 0.2303, 0.0105, 0.0499]])
# xyxy: tensor([[1101.9935,  221.7521, 1122.2007,  275.6264]])
# xyxyn: tensor([[0.5740, 0.2053, 0.5845, 0.2552]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.6691])
# data: tensor([[422.1373, 439.7846, 451.1716, 523.8344,   0.6691,   2.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[436.6544, 481.8094,  29.0343,  84.0498]])
# xywhn: tensor([[0.2274, 0.4461, 0.0151, 0.0778]])
# xyxy: tensor([[422.1373, 439.7846, 451.1716, 523.8344]])
# xyxyn: tensor([[0.2199, 0.4072, 0.2350, 0.4850]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.6562])
# data: tensor([[1.1820e+03, 2.8751e+02, 1.2033e+03, 3.5660e+02, 6.5624e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1192.6521,  322.0572,   21.2842,   69.0929]])
# xywhn: tensor([[0.6212, 0.2982, 0.0111, 0.0640]])
# xyxy: tensor([[1182.0100,  287.5107, 1203.2942,  356.6036]])
# xyxyn: tensor([[0.6156, 0.2662, 0.6267, 0.3302]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.6412])
# data: tensor([[211.8864, 318.7034, 231.5083, 393.4547,   0.6412,   1.0000]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[221.6973, 356.0790,  19.6219,  74.7514]])
# xywhn: tensor([[0.1155, 0.3297, 0.0102, 0.0692]])
# xyxy: tensor([[211.8864, 318.7034, 231.5083, 393.4547]])
# xyxyn: tensor([[0.1104, 0.2951, 0.1206, 0.3643]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.6404])
# data: tensor([[1.2237e+03, 2.3131e+02, 1.2441e+03, 2.9075e+02, 6.4035e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1233.9189,  261.0285,   20.3613,   59.4466]])
# xywhn: tensor([[0.6427, 0.2417, 0.0106, 0.0550]])
# xyxy: tensor([[1223.7383,  231.3052, 1244.0996,  290.7518]])
# xyxyn: tensor([[0.6374, 0.2142, 0.6480, 0.2692]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.])
# conf: tensor([0.6356])
# data: tensor([[1.0726e+03, 3.3967e+02, 1.0989e+03, 4.1826e+02, 6.3565e-01, 3.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1085.7852,  378.9645,   26.2958,   78.5918]])
# xywhn: tensor([[0.5655, 0.3509, 0.0137, 0.0728]])
# xyxy: tensor([[1072.6373,  339.6686, 1098.9331,  418.2604]])
# xyxyn: tensor([[0.5587, 0.3145, 0.5724, 0.3873]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.5972])
# data: tensor([[1.1312e+03, 2.2271e+02, 1.1456e+03, 2.6616e+02, 5.9719e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1138.4336,  244.4339,   14.3705,   43.4559]])
# xywhn: tensor([[0.5929, 0.2263, 0.0075, 0.0402]])
# xyxy: tensor([[1131.2483,  222.7059, 1145.6188,  266.1618]])
# xyxyn: tensor([[0.5892, 0.2062, 0.5967, 0.2464]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.5708])
# data: tensor([[9.4502e+02, 2.3082e+02, 9.6625e+02, 2.8789e+02, 5.7078e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[955.6360, 259.3573,  21.2271,  57.0712]])
# xywhn: tensor([[0.4977, 0.2401, 0.0111, 0.0528]])
# xyxy: tensor([[945.0225, 230.8217, 966.2496, 287.8929]])
# xyxyn: tensor([[0.4922, 0.2137, 0.5033, 0.2666]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.5084])
# data: tensor([[4.8847e+02, 3.7130e+02, 5.2219e+02, 4.4915e+02, 5.0838e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[505.3296, 410.2249,  33.7246,  77.8407]])
# xywhn: tensor([[0.2632, 0.3798, 0.0176, 0.0721]])
# xyxy: tensor([[488.4673, 371.3046, 522.1919, 449.1453]])
# xyxyn: tensor([[0.2544, 0.3438, 0.2720, 0.4159]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.5041])
# data: tensor([[9.8822e+02, 2.2475e+02, 1.0050e+03, 2.8111e+02, 5.0414e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[996.6156, 252.9263,  16.7948,  56.3586]])
# xywhn: tensor([[0.5191, 0.2342, 0.0087, 0.0522]])
# xyxy: tensor([[ 988.2182,  224.7470, 1005.0130,  281.1056]])
# xyxyn: tensor([[0.5147, 0.2081, 0.5234, 0.2603]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.4821])
# data: tensor([[1.2058e+03, 2.7813e+02, 1.2260e+03, 3.4880e+02, 4.8208e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1215.8833,  313.4639,   20.1423,   70.6757]])
# xywhn: tensor([[0.6333, 0.2902, 0.0105, 0.0654]])
# xyxy: tensor([[1205.8121,  278.1261, 1225.9545,  348.8017]])
# xyxyn: tensor([[0.6280, 0.2575, 0.6385, 0.3230]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.4467])
# data: tensor([[9.7822e+02, 3.6709e+02, 1.0025e+03, 4.4757e+02, 4.4671e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[990.3719, 407.3327,  24.3043,  80.4809]])
# xywhn: tensor([[0.5158, 0.3772, 0.0127, 0.0745]])
# xyxy: tensor([[ 978.2197,  367.0922, 1002.5240,  447.5731]])
# xyxyn: tensor([[0.5095, 0.3399, 0.5221, 0.4144]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.3801])
# data: tensor([[1.0717e+03, 3.3899e+02, 1.0983e+03, 4.1924e+02, 3.8013e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1084.9668,  379.1172,   26.5726,   80.2507]])
# xywhn: tensor([[0.5651, 0.3510, 0.0138, 0.0743]])
# xyxy: tensor([[1071.6804,  338.9919, 1098.2531,  419.2426]])
# xyxyn: tensor([[0.5582, 0.3139, 0.5720, 0.3882]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.3730])
# data: tensor([[4.8622e+02, 3.6928e+02, 5.1346e+02, 4.5140e+02, 3.7297e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[499.8376, 410.3413,  27.2448,  82.1237]])
# xywhn: tensor([[0.2603, 0.3799, 0.0142, 0.0760]])
# xyxy: tensor([[486.2151, 369.2794, 513.4600, 451.4031]])
# xyxyn: tensor([[0.2532, 0.3419, 0.2674, 0.4180]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.2755])
# data: tensor([[1.2090e+03, 2.5501e+02, 1.2250e+03, 3.0879e+02, 2.7546e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1216.9865,  281.8995,   15.9993,   53.7725]])
# xywhn: tensor([[0.6338, 0.2610, 0.0083, 0.0498]])
# xyxy: tensor([[1208.9868,  255.0132, 1224.9861,  308.7857]])
# xyxyn: tensor([[0.6297, 0.2361, 0.6380, 0.2859]])
